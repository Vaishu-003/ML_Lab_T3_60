# %%
import pandas as pd 
import numpy as np

df = pd.read_csv('C:\\Users\\vaishnavi\\OneDrive\\Desktop\\1000_popular_hindi_spotify.csv')
df.head(10)
# Out:
#                        ID                          Name  Popularity  \
# 0  4nc6XiUze2Yh7wFueGOPv7        Chaleya (From "Jawan")          83
# 1  2wAiFWjRupWmnDkQcu91MF                Rumah Ke Rumah          80
# 2  7J0isBrUxhIYZVdrBOOlIh                        Cincin          78
# 3  2dIBMHByUGcNPzmYBJ6OAj                      Evaluasi          78
# 4  5drW6PGRxkE6MxttzVLNk5                    Secukupnya          76
# 5  56zZ48jdyY2oDXHVnwg5Di                     Tum Hi Ho          75
# 6  3CBxVM0zGj41BQtE6m7gwb                      Membasuh          70
# 7  1bcIiU5FWRa2IYBqx0bk67                      Evakuasi          69
# 8  5d6K5YMfby3mRfsTeTxUV3  Laagi Lagan Shankara - Hindi          68
# 9  3kj14iUwv0rvTweOr9P2ut                      Mata Air          68
#
#                                              Artists
# 0  Anirudh Ravichander, Arijit Singh, Shilpa Rao,...
# 1                                             Hindia
# 2                                             Hindia
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          950 non-null    object
#  1   Name        950 non-null    object
#  2   Popularity  950 non-null    int64
#  3   Artists     950 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 29.8+ KB

# %%
to_drop = ['ID']      

df.drop(to_drop, inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        950 non-null    object
#  1   Popularity  950 non-null    int64
#  2   Artists     950 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 22.4+ KB

# %%
df.head(50)
# Out:
#                                                 Name  Popularity  \
# 0                             Chaleya (From "Jawan")          83
# 1                                     Rumah Ke Rumah          80
# 2                                             Cincin          78
# 3                                           Evaluasi          78
# 4                                         Secukupnya          76
# 5                                          Tum Hi Ho          75
# 6                                           Membasuh          70
# 7                                           Evakuasi          69
# 8                       Laagi Lagan Shankara - Hindi          68
# 9                                           Mata Air          68
# 10                               Oh Ho Ho Ho (Remix)          66
# 11            Berdansalah, Karir Ini Tak Ada Artinya          66
# 12                                      Hindi Na Nga          65
# ...

# %%
df.loc[200]
# Out:
# Name             Titli Rani
# Popularity               39
# Artists       Jayalakshmi K
# Name: 200, dtype: object

# %%
df.loc[300]
# Out:
# Name          gazing up
# Popularity           33
# Artists          Hindie
# Name: 300, dtype: object

# %%
df.tail()
# Out:
#                            Name  Popularity  \
# 945             Deja Vu - Remix           0
# 946         Halla Macha - Remix           0
# 947              Laadla - Remix           0
# 948  Gabbar Bhi Nachega - Remix           0
# 949              Da One - Remix           0
#
#                                         Artists
# 945  Hindi Song, Hindi Music, Hindi Remix Group
# 946  Hindi Song, Hindi Music, Hindi Remix Group
# 947  Hindi Song, Hindi Music, Hindi Remix Group
# 948  Hindi Song, Hindi Music, Hindi Remix Group
# 949  Hindi Song, Hindi Music, Hindi Remix Group

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945     True
# 946     True
# 947     True
# 948    False
# 949     True
# Length: 950, dtype: bool

# %%
df.isnull()
# Out:
#       Name  Popularity  Artists
# 0    False       False    False
# 1    False       False    False
# 2    False       False    False
# 3    False       False    False
# 4    False       False    False
# ..     ...         ...      ...
# 945  False       False    False
# 946  False       False    False
# 947  False       False    False
# 948  False       False    False
# 949  False       False    False
#
# [950 rows x 3 columns]

# %%
df.loc[df.duplicated(keep=False)]
# Out:
#                                  Name  Popularity  \
# 869                             Hindi           0
# 885                             Hindi           0
# 887                             Hindi           0
# 888                             Hindi           0
# 904               Love Prayer - Remix           0
# 906                Chill Mode - Remix           0
# 908               Halla Macha - Remix           0
# 909                    Da One - Remix           0
# 910                   No News - Remix           0
# 912  Pyaar Hota Kayi Baar Hai - Remix           0
# 913                  Na Maane - Remix           0
# 914                 All Right - Remix           0
# 916             Mangala Kaali - Remix           0
# 917        Maine Pi Rakhi Hai - Remix           0
# 919                 All Right - Remix           0
# 920                 All Right - Remix           0
# 921                    Laadla - Remix           0
# 922             Mangala Kaali - Remix           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        950 non-null    object
#  1   Popularity  950 non-null    int64
#  2   Artists     950 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 22.4+ KB
